# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("C:\\Users\\HP Probook4540s\\Desktop\\analysis\\Healthcare-Diabetes.csv")
df
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X= df.drop(["Id","Outcome"],axis=1)
y = df["Outcome"]

# %%
X
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               6      148             72             35        0  33.6
# 1               1       85             66             29        0  26.6
# 2               8      183             64              0        0  23.3
# 3               1       89             66             23       94  28.1
# 4               0      137             40             35      168  43.1
# ...           ...      ...            ...            ...      ...   ...
# 2763            2       75             64             24       55  29.7
# 2764            8      179             72             42      130  32.7
# 2765            6       85             78              0        0  31.2
# 2766            0      129            110             46      130  67.1
# 2767            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age
# 0                        0.627   50
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
X_train
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 149             2       90             70             17        0  27.3
# 439             6      107             88              0        0  36.8
# 509             8      120             78              0        0  25.0
# 1936            5      126             78             27       22  29.6
# 1436            6       98             58             33      190  34.0
# ...           ...      ...            ...            ...      ...   ...
# 1638            4       95             64              0        0  32.0
# 1095           10      179             70              0        0  35.1
# 1130            5      103            108             37        0  39.2
# 1294            1       97             64             19       82  18.2
# 860             7       81             78             40       48  46.7
#
#       DiabetesPedigreeFunction  Age
# 149                      0.085   22
# ...

# %%
X_test
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1378            3      106             54             21      158  30.9
# 839             5      139             64             35      140  28.6
# 2164            9      164             84             21        0  30.8
# 2619           10      101             76             48      180  32.9
# 927            17      163             72             41      114  40.9
# ...           ...      ...            ...            ...      ...   ...
# 2463            1       92             62             25       41  19.5
# 958             3      111             62              0        0  22.6
# 1091           13      152             90             33       29  26.8
# 1055            1      119             86             39      220  45.6
# 2297            1      144             82             40        0  41.3
#
#       DiabetesPedigreeFunction  Age
# 1378                     0.292   24
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score
ypred = log_reg.predict(X_test)
print("test accuracy:", accuracy_score(y_test,ypred))
# Out:
# test accuracy: 0.776173285198556

# %%
log_reg.predict([[4,105,54,140,21,30.8,0.283,25]])
# Out:
# array([0], dtype=int64)

# %%
X_new = pd.DataFrame({"Pregnancies":[4,5],
                      "Glucose":[105,107],
                      "BloodPressure":[54,64],
                      "SkinThickness":[21,19],
                      "Insulin":[140,130],
                      "BMI":[30.8,31],
                      "DiabetesPedigreeFunction":[0.283,0.314],
                      "Age":[25,30]})
future_prediction = log_reg.predict(X_new)
print("predicted:",future_prediction)
# Out:
# predicted: [0 0]

# %%
X_new = pd.DataFrame({"Pregnancies":[9,5],
                      "Glucose":[164,107],
                      "BloodPressure":[84,64],
                      "SkinThickness":[21,19],
                      "Insulin":[0,130],
                      "BMI":[30.8,31],
                      "DiabetesPedigreeFunction":[0.283,0.314],
                      "Age":[25,30]})
future_prediction = log_reg.predict(X_new)
print("predicted:",future_prediction)
# Out:
# predicted: [1 0]

# %%
from sklearn.ensemble import RandomForestClassifier
estimator = RandomForestClassifier(n_estimators = 5)

# %%
estimator.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
ypred = estimator.predict(X_test)
len(ypred)
# Out:
# 277

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score
ypred = estimator.predict(X_test)
print("test accuracy:", accuracy_score(y_test,ypred))
# Out:
# test accuracy: 1.0
